# %%
import pandas as pd
import numpy as np
pd.set_option("display.max_columns", None)

# %%
listing = pd.read_csv('listings.csv', encoding='utf-8') #read Airbnb listing dataset 
listing = listing.drop(['listing_url', 'scrape_id', 'last_scraped','description','neighborhood_overview',
'picture_url','host_url', 'host_about','host_response_time','host_response_rate','host_acceptance_rate',
'host_thumbnail_url', 'host_picture_url','host_verifications','host_has_profile_pic','host_identity_verified',
'minimum_minimum_nights','maximum_minimum_nights','minimum_maximum_nights',
'maximum_maximum_nights', 'minimum_nights_avg_ntm','maximum_nights_avg_ntm','calendar_updated',
'first_review','last_review','license','instant_bookable','calculated_host_listings_count',
'calculated_host_listings_count_entire_homes', 'calculated_host_listings_count_private_rooms',
'calculated_host_listings_count_shared_rooms', 'number_of_reviews_ltm','number_of_reviews_l30d'], axis=1)

# Deleting irrelevant fields of this project

# %%
# Show listing dataset intereactively
import mitosheet
mitosheet.sheet(listing, view_df=True)
# Out:
# MitoWidget(analysis_data_json='{"analysisName": "UUID-174a835f-39c4-4e1c-b576-4ce97b600d91", "code": {"imports…

# %%
listing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28125 entries, 0 to 28124
# Data columns (total 41 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id                            28125 non-null  int64
#  1   name                          28124 non-null  object
#  2   host_id                       28125 non-null  int64
#  3   host_name                     28113 non-null  object
#  4   host_since                    28118 non-null  object
#  5   host_location                 28096 non-null  object
#  6   host_is_superhost             28118 non-null  object
#  7   host_neighbourhood            14551 non-null  object
#  8   host_listings_count           28118 non-null  float64
#  9   host_total_listings_count     28118 non-null  float64
#  10  neighbourhood                 23334 non-null  object
#  11  neighbourhood_cleansed        28125 non-null  object
#  12  neighbourhood_group_cleansed  0 non-null      float64
#  13  latitude                      28125 non-null  float64
#  14  longitude                     28125 non-null  float64
#  15  property_type                 28125 non-null  object
#  16  room_type                     28125 non-null  object
#  17  accommodates                  28125 non-null  int64
#  18  bathrooms                     0 non-null      float64
#  19  bathrooms_text                28073 non-null  object
#  20  bedrooms                      27162 non-null  float64
#  21  beds                          27915 non-null  float64
#  22  amenities                     28125 non-null  object
#  23  price                         28125 non-null  object
#  24  minimum_nights                28125 non-null  int64
#  25  maximum_nights                28125 non-null  int64
#  26  has_availability              28125 non-null  object
#  27  availability_30               28125 non-null  int64
#  28  availability_60               28125 non-null  int64
#  29  availability_90               28125 non-null  int64
#  30  availability_365              28125 non-null  int64
#  31  calendar_last_scraped         28125 non-null  object
#  32  number_of_reviews             28125 non-null  int64
#  33  review_scores_rating          17632 non-null  float64
#  34  review_scores_accuracy        17139 non-null  float64
#  35  review_scores_cleanliness     17139 non-null  float64
#  36  review_scores_checkin         17137 non-null  float64
#  37  review_scores_communication   17139 non-null  float64
#  38  review_scores_location        17136 non-null  float64
#  39  review_scores_value           17136 non-null  float64
#  40  reviews_per_month             17632 non-null  float64
# dtypes: float64(16), int64(10), object(15)
# memory usage: 8.8+ MB

# %%
from qgis.core import *

# %%
conda install -c conda-forge qgis -y
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: \
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/noarch::jupyterlab==3.0.14=pyhd3eb1b0_1
#   - defaults/noarch::jupyterlab_server==2.4.0=pyhd3eb1b0_0
#   - defaults/noarch::conda-repo-cli==1.0.4=pyhd3eb1b0_0
#   - defaults/osx-64::conda==4.11.0=py38hecd8cb5_0
#   - defaults/noarch::sphinx==4.0.1=pyhd3eb1b0_0
#   - defaults/osx-64::_ipyw_jlab_nb_ext_conf==0.1.0=py38_0
#   - defaults/osx-64::anaconda-client==1.7.2=py38_0
#   - defaults/osx-64::scrapy==2.4.1=py38hecd8cb5_0
#   - defaults/noarch::numpydoc==1.1.0=pyhd3eb1b0_1
#   - defaults/osx-64::anaconda-navigator==2.1.0=py38hecd8cb5_0
#   - defaults/osx-64::anaconda==2021.05=py38_0
#   - defaults/noarch::anaconda-project==0.9.1=pyhd3eb1b0_1
#   - defaults/osx-64::spyder==4.2.5=py38hecd8cb5_0
#   - defaults/osx-64::conda-build==3.21.4=py38hecd8cb5_0
#   - defaults/noarch::conda-token==0.3.0=pyhd3eb1b0_0
#   - defaults/osx-64::parsel==1.5.2=py38hecd8cb5_0
# failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: |
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/noarch::jupyterlab==3.0.14=pyhd3eb1b0_1
#   - defaults/noarch::jupyterlab_server==2.4.0=pyhd3eb1b0_0
#   - defaults/noarch::conda-repo-cli==1.0.4=pyhd3eb1b0_0
#   - defaults/osx-64::conda==4.11.0=py38hecd8cb5_0
#   - defaults/noarch::sphinx==4.0.1=pyhd3eb1b0_0
#   - defaults/osx-64::_ipyw_jlab_nb_ext_conf==0.1.0=py38_0
#   - defaults/osx-64::anaconda-client==1.7.2=py38_0
#   - defaults/osx-64::scrapy==2.4.1=py38hecd8cb5_0
#   - defaults/noarch::numpydoc==1.1.0=pyhd3eb1b0_1
#   - defaults/osx-64::anaconda-navigator==2.1.0=py38hecd8cb5_0
#   - defaults/osx-64::anaconda==2021.05=py38_0
#   - defaults/noarch::anaconda-project==0.9.1=pyhd3eb1b0_1
#   - defaults/osx-64::spyder==4.2.5=py38hecd8cb5_0
#   - defaults/osx-64::conda-build==3.21.4=py38hecd8cb5_0
#   - defaults/noarch::conda-token==0.3.0=pyhd3eb1b0_0
#   - defaults/osx-64::parsel==1.5.2=py38hecd8cb5_0
# done
#
# ## Package Plan ##
#
#   environment location: /Users/oo/opt/anaconda3
#
#   added / updated specs:
#     - qgis
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _anaconda_depends-2020.07  |           py38_0           6 KB
#     anaconda-custom            |           py38_1          35 KB
#     aws-c-common-0.4.57        |       hb1e8313_1         140 KB
#     aws-c-event-stream-0.1.6   |       h23ab428_5          21 KB
#     aws-checksums-0.1.9        |       hb1e8313_0          47 KB
#     aws-sdk-cpp-1.8.185        |       he271ece_0         1.6 MB
#     boost-cpp-1.72.0           |       hdf9ef73_0        19.1 MB  conda-forge
#     ca-certificates-2021.10.8  |       h033912b_0         139 KB  conda-forge
#     cached-property-1.5.2      |       hd8ed1ab_1           4 KB  conda-forge
#     cached_property-1.5.2      |     pyha770c72_1          11 KB  conda-forge
#     cairo-1.16.0               |    hec6a9b0_1003         1.3 MB  conda-forge
#     certifi-2021.10.8          |   py38h50d1736_1         145 KB  conda-forge
#     cfitsio-3.470              |       h389770f_2         1.4 MB  conda-forge
#     charset-normalizer-2.0.12  |     pyhd8ed1ab_0          35 KB  conda-forge
#     coverage-6.3.2             |   py38hed1de0f_0         236 KB  conda-forge
#     curl-7.71.1                |       hbdca1c0_1         133 KB  conda-forge
#     exiv2-0.27.1               |       ha4feea6_0         1.1 MB  conda-forge
#     fontconfig-2.13.1          |    h10f422b_1005         271 KB  conda-forge
#     freetds-1.1.15             |       h6ad6909_0         2.3 MB  conda-forge
#     freexl-1.0.6               |       h0d85af4_0          42 KB  conda-forge
#     gdal-3.0.2                 |   py38ha6ec53f_1         1.1 MB
#     geos-3.8.0                 |       h4a8c4bd_1         898 KB  conda-forge
#     geotiff-1.6.0              |       h02c1893_0         120 KB
#     giflib-5.2.1               |       hbcb3906_2          71 KB  conda-forge
#     gsl-2.5                    |       ha2d443c_1         2.7 MB  conda-forge
#     h5py-3.3.0                 |nompi_py38h9a16e60_100         1.1 MB  conda-forge
#     hdf4-4.2.13                |    h84186c3_1003         882 KB  conda-forge
#     hdf5-1.10.6                |       hdbbcd12_0         3.0 MB
#     httplib2-0.20.4            |     pyhd8ed1ab_0          96 KB  conda-forge
#     icu-64.2                   |       h6de7cb9_1        12.3 MB  conda-forge
#     jpeg-9e                    |       h0d85af4_0         252 KB  conda-forge
#     json-c-0.13.1              |    h575e443_1002          66 KB  conda-forge
#     kealib-1.4.14              |       h7bbef82_0         139 KB
#     krb5-1.17.1                |       h14dd6a4_2         1.2 MB  conda-forge
#     libblas-3.9.0              |            9_mkl          12 KB  conda-forge
#     libcblas-3.9.0             |            9_mkl          11 KB  conda-forge
#     libclang-9.0.1             |default_hf57f61e_0        18.0 MB  conda-forge
#     libcurl-7.71.1             |       he6690cf_1         295 KB  conda-forge
#     libdap4-3.19.1             |    hae55d67_1000         1.7 MB  conda-forge
#     libgdal-3.0.2              |       ha1444b2_1        10.4 MB
#     libkml-1.3.0               |    h169b8f9_1011         482 KB  conda-forge
#     libllvm9-9.0.1             |       h7475705_1        19.9 MB  conda-forge
#     libnetcdf-4.6.1            |       hfd9a460_4         782 KB
#     libpq-12.3                 |       h7049927_3         2.6 MB  conda-forge
#     libspatialite-4.3.0a       |    h9691d84_1033         3.1 MB  conda-forge
#     libtasn1-4.18.0            |       h0d85af4_0         105 KB  conda-forge
#     libxml2-2.9.10             |       h53d96d6_0         1.2 MB  conda-forge
#     libxslt-1.1.33             |       h320ff13_0         526 KB  conda-forge
#     libzip-1.8.0               |       h8b0c345_1         117 KB  conda-forge
#     lxml-4.6.3                 |   py38h6ea4786_0         1.2 MB  conda-forge
#     nose2-0.9.2                |             py_0          91 KB  conda-forge
#     nspr-4.20                  |    h0a44026_1000         748 KB  conda-forge
#     nss-3.47                   |       hc0980d9_0         1.8 MB  conda-forge
#     openjpeg-2.3.1             |       h254dc36_3         411 KB  conda-forge
#     openssl-1.1.1l             |       h0d85af4_0         1.9 MB  conda-forge
#     owslib-0.25.0              |     pyhd8ed1ab_0         135 KB  conda-forge
#     pathtools-0.1.2            |             py_1           8 KB  conda-forge
#     pixman-0.38.0              |    h01d97ff_1003         611 KB  conda-forge
#     plotly-5.6.0               |     pyhd8ed1ab_0         6.9 MB  conda-forge
#     poppler-0.90.1             |       h6db0e4e_0         1.7 MB  conda-forge
#     poppler-data-0.4.11        |       hd8ed1ab_0         3.6 MB  conda-forge
#     postgresql-12.3            |       he852019_3         4.5 MB  conda-forge
#     proj-6.2.1                 |       h773a61f_0        10.0 MB  conda-forge
#     psycopg2-2.8.6             |   py38h6b4ec92_1         150 KB  conda-forge
#     pyproj-2.4.2.post1         |   py38h03a428a_0         315 KB  conda-forge
#     pyqt-5.12.3                |   py38hf180056_3         5.2 MB  conda-forge
#     pytables-3.6.1             |   py38h138c9cc_2         1.4 MB  conda-forge
#     python_abi-3.8             |           2_cp38           4 KB  conda-forge
#     qca-2.2.1                  |       hc763db3_3         880 KB  conda-forge
#     qgis-3.10.2                |   py38hf9e775f_0        68.0 MB  conda-forge
#     qjson-0.9.0                |    hc763db3_1006          63 KB  conda-forge
#     qscintilla2-2.11.2         |   py38h2815f34_2         1.6 MB  conda-forge
#     qt-5.12.5                  |       h514805e_3        86.8 MB  conda-forge
#     qtkeychain-0.10.0          |       h2815f34_0          29 KB  conda-forge
#     qtlocation-5.12.5          |       h4a8c4bd_0           7 KB  conda-forge
#     qtserialport-5.9.8         |       hc763db3_1          44 KB  conda-forge
#     qwt-6.1.5                  |       h2815f34_0         4.0 MB  conda-forge
#     qwtpolar-1.1.1             |       h2815f34_7         436 KB  conda-forge
#     requests-2.27.1            |     pyhd8ed1ab_0          53 KB  conda-forge
#     snappy-1.1.8               |       h4a8c4bd_3          36 KB  conda-forge
#     tenacity-8.0.1             |     pyhd8ed1ab_0          21 KB  conda-forge
#     tiledb-2.2.9               |       hdc16fd3_0         1.5 MB
#     tzcode-2021e               |       h0d85af4_0          64 KB  conda-forge
#     xerces-c-3.2.3             |       h8f8adb3_0         1.5 MB  conda-forge
#     zstd-1.4.9                 |       h322a384_0         476 KB
#     ------------------------------------------------------------
#                                            Total:       316.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   _anaconda_depends  pkgs/main/osx-64::_anaconda_depends-2020.07-py38_0
#   aws-c-common       pkgs/main/osx-64::aws-c-common-0.4.57-hb1e8313_1
#   aws-c-event-stream pkgs/main/osx-64::aws-c-event-stream-0.1.6-h23ab428_5
#   aws-checksums      pkgs/main/osx-64::aws-checksums-0.1.9-hb1e8313_0
#   aws-sdk-cpp        pkgs/main/osx-64::aws-sdk-cpp-1.8.185-he271ece_0
#   boost-cpp          conda-forge/osx-64::boost-cpp-1.72.0-hdf9ef73_0
#   cached-property    conda-forge/noarch::cached-property-1.5.2-hd8ed1ab_1
#   cached_property    conda-forge/noarch::cached_property-1.5.2-pyha770c72_1
#   cairo              conda-forge/osx-64::cairo-1.16.0-hec6a9b0_1003
#   cfitsio            conda-forge/osx-64::cfitsio-3.470-h389770f_2
#   charset-normalizer conda-forge/noarch::charset-normalizer-2.0.12-pyhd8ed1ab_0
#   coverage           conda-forge/osx-64::coverage-6.3.2-py38hed1de0f_0
#   exiv2              conda-forge/osx-64::exiv2-0.27.1-ha4feea6_0
#   fontconfig         conda-forge/osx-64::fontconfig-2.13.1-h10f422b_1005
#   freexl             conda-forge/osx-64::freexl-1.0.6-h0d85af4_0
#   gdal               pkgs/main/osx-64::gdal-3.0.2-py38ha6ec53f_1
#   geos               conda-forge/osx-64::geos-3.8.0-h4a8c4bd_1
#   geotiff            pkgs/main/osx-64::geotiff-1.6.0-h02c1893_0
#   giflib             conda-forge/osx-64::giflib-5.2.1-hbcb3906_2
#   hdf4               conda-forge/osx-64::hdf4-4.2.13-h84186c3_1003
#   httplib2           conda-forge/noarch::httplib2-0.20.4-pyhd8ed1ab_0
#   json-c             conda-forge/osx-64::json-c-0.13.1-h575e443_1002
#   kealib             pkgs/main/osx-64::kealib-1.4.14-h7bbef82_0
#   libblas            conda-forge/osx-64::libblas-3.9.0-9_mkl
#   libcblas           conda-forge/osx-64::libcblas-3.9.0-9_mkl
#   libclang           conda-forge/osx-64::libclang-9.0.1-default_hf57f61e_0
#   libdap4            conda-forge/osx-64::libdap4-3.19.1-hae55d67_1000
#   libgdal            pkgs/main/osx-64::libgdal-3.0.2-ha1444b2_1
#   libkml             conda-forge/osx-64::libkml-1.3.0-h169b8f9_1011
#   libllvm9           conda-forge/osx-64::libllvm9-9.0.1-h7475705_1
#   libnetcdf          pkgs/main/osx-64::libnetcdf-4.6.1-hfd9a460_4
#   libpq              conda-forge/osx-64::libpq-12.3-h7049927_3
#   libspatialite      conda-forge/osx-64::libspatialite-4.3.0a-h9691d84_1033
#   libtasn1           conda-forge/osx-64::libtasn1-4.18.0-h0d85af4_0
#   libzip             conda-forge/osx-64::libzip-1.8.0-h8b0c345_1
#   lxml               conda-forge/osx-64::lxml-4.6.3-py38h6ea4786_0
#   nose2              conda-forge/noarch::nose2-0.9.2-py_0
#   nspr               conda-forge/osx-64::nspr-4.20-h0a44026_1000
#   nss                conda-forge/osx-64::nss-3.47-hc0980d9_0
#   openjpeg           conda-forge/osx-64::openjpeg-2.3.1-h254dc36_3
#   owslib             conda-forge/noarch::owslib-0.25.0-pyhd8ed1ab_0
#   pathtools          conda-forge/noarch::pathtools-0.1.2-py_1
#   pixman             conda-forge/osx-64::pixman-0.38.0-h01d97ff_1003
#   plotly             conda-forge/noarch::plotly-5.6.0-pyhd8ed1ab_0
#   poppler            conda-forge/osx-64::poppler-0.90.1-h6db0e4e_0
#   poppler-data       conda-forge/noarch::poppler-data-0.4.11-hd8ed1ab_0
#   postgresql         conda-forge/osx-64::postgresql-12.3-he852019_3
#   proj               conda-forge/osx-64::proj-6.2.1-h773a61f_0
#   psycopg2           conda-forge/osx-64::psycopg2-2.8.6-py38h6b4ec92_1
#   pyproj             conda-forge/osx-64::pyproj-2.4.2.post1-py38h03a428a_0
#   python_abi         conda-forge/osx-64::python_abi-3.8-2_cp38
#   qca                conda-forge/osx-64::qca-2.2.1-hc763db3_3
#   qgis               conda-forge/osx-64::qgis-3.10.2-py38hf9e775f_0
#   qjson              conda-forge/osx-64::qjson-0.9.0-hc763db3_1006
#   qscintilla2        conda-forge/osx-64::qscintilla2-2.11.2-py38h2815f34_2
#   qtkeychain         conda-forge/osx-64::qtkeychain-0.10.0-h2815f34_0
#   qtlocation         conda-forge/osx-64::qtlocation-5.12.5-h4a8c4bd_0
#   qtserialport       conda-forge/osx-64::qtserialport-5.9.8-hc763db3_1
#   qwt                conda-forge/osx-64::qwt-6.1.5-h2815f34_0
#   qwtpolar           conda-forge/osx-64::qwtpolar-1.1.1-h2815f34_7
#   requests           conda-forge/noarch::requests-2.27.1-pyhd8ed1ab_0
#   snappy             conda-forge/osx-64::snappy-1.1.8-h4a8c4bd_3
#   tenacity           conda-forge/noarch::tenacity-8.0.1-pyhd8ed1ab_0
#   tiledb             pkgs/main/osx-64::tiledb-2.2.9-hdc16fd3_0
#   tzcode             conda-forge/osx-64::tzcode-2021e-h0d85af4_0
#   xerces-c           conda-forge/osx-64::xerces-c-3.2.3-h8f8adb3_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    pkgs/main::ca-certificates-2021.4.13-~ --> conda-forge::ca-certificates-2021.10.8-h033912b_0
#   certifi            pkgs/main::certifi-2020.12.5-py38hecd~ --> conda-forge::certifi-2021.10.8-py38h50d1736_1
#   gsl                         pkgs/main::gsl-2.4-h1de35cc_4 --> conda-forge::gsl-2.5-ha2d443c_1
#   h5py                pkgs/main::h5py-2.10.0-py38h3134771_0 --> conda-forge::h5py-3.3.0-nompi_py38h9a16e60_100
#   hdf5                                    1.10.4-hfa1e0ec_0 --> 1.10.6-hdbbcd12_0
#   icu                        pkgs/main::icu-58.2-h0a44026_3 --> conda-forge::icu-64.2-h6de7cb9_1
#   jpeg                        pkgs/main::jpeg-9b-he5867d9_2 --> conda-forge::jpeg-9e-h0d85af4_0
#   openssl              pkgs/main::openssl-1.1.1k-h9ed2024_0 --> conda-forge::openssl-1.1.1l-h0d85af4_0
#   pyqt                 pkgs/main::pyqt-5.9.2-py38h655552a_2 --> conda-forge::pyqt-5.12.3-py38hf180056_3
#   pytables           pkgs/main::pytables-3.6.1-py38h4727e9~ --> conda-forge::pytables-3.6.1-py38h138c9cc_2
#   qt                         pkgs/main::qt-5.9.7-h468cd18_1 --> conda-forge::qt-5.12.5-h514805e_3
#   zstd                                     1.4.5-h41d2c2f_0 --> 1.4.9-h322a384_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   curl                    pkgs/main::curl-7.71.1-hb0a8c7a_1 --> conda-forge::curl-7.71.1-hbdca1c0_1
#   freetds              pkgs/main::freetds-1.1.15-h37b1a22_0 --> conda-forge::freetds-1.1.15-h6ad6909_0
#   krb5                    pkgs/main::krb5-1.18.2-h75d18d8_0 --> conda-forge::krb5-1.17.1-h14dd6a4_2
#   libcurl              pkgs/main::libcurl-7.71.1-h8a08a2b_1 --> conda-forge::libcurl-7.71.1-he6690cf_1
#   libxml2              pkgs/main::libxml2-2.9.10-h7cdb67c_3 --> conda-forge::libxml2-2.9.10-h53d96d6_0
#   libxslt              pkgs/main::libxslt-1.1.34-h83b36ba_0 --> conda-forge::libxslt-1.1.33-h320ff13_0
#
# The following packages will be DOWNGRADED:
#
#   anaconda                                   2021.05-py38_0 --> custom-py38_1
#
#
#
# Downloading and Extracting Packages
# aws-sdk-cpp-1.8.185  | 1.6 MB    | ##################################### | 100%
# giflib-5.2.1         | 71 KB     | ##################################### | 100%
# libspatialite-4.3.0a | 3.1 MB    | ##################################### | 100%
# aws-checksums-0.1.9  | 47 KB     | ##################################### | 100%
# nose2-0.9.2          | 91 KB     | ##################################### | 100%
# libllvm9-9.0.1       | 19.9 MB   | ##################################### | 100%
# tenacity-8.0.1       | 21 KB     | ##################################### | 100%
# krb5-1.17.1          | 1.2 MB    | ##################################### | 100%
# geotiff-1.6.0        | 120 KB    | ##################################### | 100%
# gdal-3.0.2           | 1.1 MB    | ##################################### | 100%
# libxml2-2.9.10       | 1.2 MB    | ##################################### | 100%
# proj-6.2.1           | 10.0 MB   | ##################################### | 100%
# json-c-0.13.1        | 66 KB     | ##################################### | 100%
# freetds-1.1.15       | 2.3 MB    | ##################################### | 100%
# gsl-2.5              | 2.7 MB    | ##################################### | 100%
# fontconfig-2.13.1    | 271 KB    | ##################################### | 100%
# qt-5.12.5            | 86.8 MB   | ##################################### | 100%
# requests-2.27.1      | 53 KB     | ##################################### | 100%
# cached_property-1.5. | 11 KB     | ##################################### | 100%
# curl-7.71.1          | 133 KB    | ##################################### | 100%
# qca-2.2.1            | 880 KB    | ##################################### | 100%
# qtserialport-5.9.8   | 44 KB     | ##################################### | 100%
# tzcode-2021e         | 64 KB     | ##################################### | 100%
# libkml-1.3.0         | 482 KB    | ##################################### | 100%
# pathtools-0.1.2      | 8 KB      | ##################################### | 100%
# libzip-1.8.0         | 117 KB    | ##################################### | 100%
# snappy-1.1.8         | 36 KB     | ##################################### | 100%
# libblas-3.9.0        | 12 KB     | ##################################### | 100%
# qjson-0.9.0          | 63 KB     | ##################################### | 100%
# xerces-c-3.2.3       | 1.5 MB    | ##################################### | 100%
# hdf5-1.10.6          | 3.0 MB    | ##################################### | 100%
# anaconda-custom      | 35 KB     | ##################################### | 100%
# libnetcdf-4.6.1      | 782 KB    | ##################################### | 100%
# libdap4-3.19.1       | 1.7 MB    | ##################################### | 100%
# zstd-1.4.9           | 476 KB    | ##################################### | 100%
# postgresql-12.3      | 4.5 MB    | ##################################### | 100%
# qwtpolar-1.1.1       | 436 KB    | ##################################### | 100%
# nspr-4.20            | 748 KB    | ##################################### | 100%
# kealib-1.4.14        | 139 KB    | ##################################### | 100%
# aws-c-event-stream-0 | 21 KB     | ##################################### | 100%
# _anaconda_depends-20 | 6 KB      | ##################################### | 100%
# pyproj-2.4.2.post1   | 315 KB    | ##################################### | 100%
# psycopg2-2.8.6       | 150 KB    | ##################################### | 100%
# cached-property-1.5. | 4 KB      | ##################################### | 100%
# libxslt-1.1.33       | 526 KB    | ##################################### | 100%
# jpeg-9e              | 252 KB    | ##################################### | 100%
# plotly-5.6.0         | 6.9 MB    | ##################################### | 100%
# geos-3.8.0           | 898 KB    | ##################################### | 100%
# qgis-3.10.2          | 68.0 MB   | ##################################### | 100%
# hdf4-4.2.13          | 882 KB    | ##################################### | 100%
# ca-certificates-2021 | 139 KB    | ##################################### | 100%
# poppler-data-0.4.11  | 3.6 MB    | ##################################### | 100%
# openssl-1.1.1l       | 1.9 MB    | ##################################### | 100%
# certifi-2021.10.8    | 145 KB    | ##################################### | 100%
# charset-normalizer-2 | 35 KB     | ##################################### | 100%
# coverage-6.3.2       | 236 KB    | ##################################### | 100%
# libclang-9.0.1       | 18.0 MB   | ##################################### | 100%
# lxml-4.6.3           | 1.2 MB    | ##################################### | 100%
# pixman-0.38.0        | 611 KB    | ##################################### | 100%
# h5py-3.3.0           | 1.1 MB    | ##################################### | 100%
# libgdal-3.0.2        | 10.4 MB   | ##################################### | 100%
# freexl-1.0.6         | 42 KB     | ##################################### | 100%
# qwt-6.1.5            | 4.0 MB    | ##################################### | 100%
# qtkeychain-0.10.0    | 29 KB     | ##################################### | 100%
# pyqt-5.12.3          | 5.2 MB    | ##################################### | 100%
# httplib2-0.20.4      | 96 KB     | ##################################### | 100%
# openjpeg-2.3.1       | 411 KB    | ##################################### | 100%
# exiv2-0.27.1         | 1.1 MB    | ##################################### | 100%
# pytables-3.6.1       | 1.4 MB    | ##################################### | 100%
# owslib-0.25.0        | 135 KB    | ##################################### | 100%
# libcurl-7.71.1       | 295 KB    | ##################################### | 100%
# libpq-12.3           | 2.6 MB    | ##################################### | 100%
# poppler-0.90.1       | 1.7 MB    | ##################################### | 100%
# qscintilla2-2.11.2   | 1.6 MB    | ##################################### | 100%
# nss-3.47             | 1.8 MB    | ##################################### | 100%
# libcblas-3.9.0       | 11 KB     | ##################################### | 100%
# qtlocation-5.12.5    | 7 KB      | ##################################### | 100%
# boost-cpp-1.72.0     | 19.1 MB   | ##################################### | 100%
# tiledb-2.2.9         | 1.5 MB    | ##################################### | 100%
# aws-c-common-0.4.57  | 140 KB    | ##################################### | 100%
# libtasn1-4.18.0      | 105 KB    | ##################################### | 100%
# python_abi-3.8       | 4 KB      | ##################################### | 100%
# icu-64.2             | 12.3 MB   | ##################################### | 100%
# cairo-1.16.0         | 1.3 MB    | ##################################### | 100%
# cfitsio-3.470        | 1.4 MB    | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: failed
#
# RemoveError: 'requests' is a dependency of conda and cannot be removed from
# conda's operating environment.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge qgis -y
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: /
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/noarch::jupyterlab==3.0.14=pyhd3eb1b0_1
#   - defaults/noarch::jupyterlab_server==2.4.0=pyhd3eb1b0_0
#   - defaults/noarch::conda-repo-cli==1.0.4=pyhd3eb1b0_0
#   - defaults/osx-64::conda==4.11.0=py38hecd8cb5_0
#   - defaults/noarch::sphinx==4.0.1=pyhd3eb1b0_0
#   - defaults/osx-64::_ipyw_jlab_nb_ext_conf==0.1.0=py38_0
#   - defaults/osx-64::anaconda-client==1.7.2=py38_0
#   - defaults/osx-64::scrapy==2.4.1=py38hecd8cb5_0
#   - defaults/noarch::numpydoc==1.1.0=pyhd3eb1b0_1
#   - defaults/osx-64::anaconda-navigator==2.1.0=py38hecd8cb5_0
#   - defaults/osx-64::anaconda==2021.05=py38_0
#   - defaults/noarch::anaconda-project==0.9.1=pyhd3eb1b0_1
#   - defaults/osx-64::spyder==4.2.5=py38hecd8cb5_0
#   - defaults/osx-64::conda-build==3.21.4=py38hecd8cb5_0
#   - defaults/noarch::conda-token==0.3.0=pyhd3eb1b0_0
#   - defaults/osx-64::parsel==1.5.2=py38hecd8cb5_0
# failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: |
